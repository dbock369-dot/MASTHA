# %%
import pandas as pd
import torch
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler 
from sklearn.metrics import r2_score
from gpytorch.mlls import ExactMarginalLogLikelihood
import gpytorch
import altair as alt
import matplotlib.pyplot as plt
import re
from scipy.stats import norm
from datetime import datetime
import os
import csv

# %%
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

def train_gp(xt_train, yt_train, training_iterations=100):
    likelihood = gpytorch.likelihoods.GaussianLikelihood()
    model = ExactGPModel(xt_train, yt_train, likelihood)

    model.train()
    likelihood.train()

    optimizer = torch.optim.Adam(model.parameters(), lr=0.2)
    mll = ExactMarginalLogLikelihood(likelihood, model)

    losses = []

    for i in range(training_iterations):
        optimizer.zero_grad()
        output = model(xt_train)
        loss = -mll(output, yt_train)
        losses.append(loss.item())
        loss.backward()
        optimizer.step()

    return model.eval(), likelihood.eval(), losses

# %%
def is_bin_column(col) -> bool:
    """
    True für:
      - 'bin_0', 'bin_1', ... (beliebige nichtnegative Integer)
      - auch für numerische Spaltennamen wie 0, 1, '0', '1' (optional nützlich)
    """
    # numerische Spaltennamen zulassen (z. B. 0, 1, 2)
    if isinstance(col, (int, np.integer)):
        return True

    s = str(col)
    if s.isdigit():                 # '0', '1', ...
        return True
    if re.fullmatch(r"bin_\d+", s): # 'bin_0', 'bin_1', ...
        return True
    return False

# %%
def data_gen(temperature, pressure, vext_str):
    dft_data = pd.read_csv("/Users/danielbock/MASTERTHESIS/MASTA/DataArchiv/dft_fckin_clean_kond_64grid.csv")
    expV_data = pd.read_csv(f"/Users/danielbock/MASTERTHESIS/MASTA/DataArchiv/Vext_allcsv/Vext_allTEMP_64grid_{vext_str}.csv")
    data = pd.merge(dft_data, expV_data, 'inner', on=["structure_name", "temperature_kelvin"])
    feature_columns = [col for col in data.columns if is_bin_column(col)]
    data = data[data.beladung_mol_per_kg > 0]
    data = data[(data.temperature_kelvin == temperature) & (data.pressure_bar == pressure)]
    return data, feature_columns

# %%
def label_feature(data, feature_columns):
    data["beladung_pro_vol"] = data["beladung_atoms"] / data["volume_kubAng"]
    
    data[feature_columns] = (
        data[feature_columns]
        .multiply(data["grid.dv"], axis=0)
        .div(data["volume_kubAng"], axis=0)
    )
    label = "beladung_pro_vol"
    normalize_feature = True
    normalize_labels = True
    return data, label

# %%
from torch.distributions import Normal

def af_log_expIm(mean, var, best_f, xi=0.01):
    """Logarithmic Expected Improvement acquisition function."""

    std = torch.sqrt(var)
    std_safe = torch.clamp(std, min=1e-9)  # Avoid division by zero
    z = (mean - best_f - xi) / std_safe
    normal = Normal(torch.zeros_like(z), torch.ones_like(z))
    cdf = normal.cdf(z)
    pdf = torch.exp(normal.log_prob(z))

    ei = std * (z * cdf + pdf)

    ei_safe = torch.clamp(ei, min=1e-9)  # Avoid log(0)
    log_ei = torch.log(ei_safe)
    return log_ei

# %%
def BO_run(data, label, feature_columns):
    candidates = data.copy()  # Zunächst gefiltert, später alle Daten
    patience = 10

    # --- Initialisierung ---
    n_initial = 1  # Anzahl der initialen Trainingspunkte
    initial_indices = candidates.nsmallest(n_initial, label).index  # hier geht auch random

    print(f"Initial training points:")
    for idx in initial_indices:
        print(f"  Index {idx}, Structure {candidates.loc[idx, 'structure_name']}, {label}: {candidates.loc[idx, label]:.4f}")

    selected = candidates.loc[initial_indices]
    candidates = candidates.drop(initial_indices)
    best = [selected[label].max()]

    best_indices = list(initial_indices)  # <-- Für test_max wichtig!

    # --- BO-Schleife ---
    for i in range(100):
        if len(best) >= patience:
            if len(np.unique(best[-patience:])) == 1:
                print(f"Early stopping at iteration {i} due to no improvement in the last {patience} iterations.")
                break

        feature_transformer = MinMaxScaler()
        label_transformer = MinMaxScaler()

        train_x = torch.tensor(feature_transformer.fit_transform(selected[feature_columns].values))
        train_y = torch.tensor(label_transformer.fit_transform(selected[[label]].values)).flatten()
        test_x = torch.tensor(feature_transformer.transform(candidates[feature_columns].values))

        model, likelihood, _ = train_gp(train_x, train_y, 250)
        with torch.no_grad():
            prediction = model(test_x)
            mean, var = prediction.mean, prediction.variance

        best_f = train_y.max()
        log_ei = af_log_expIm(mean, var, best_f, 0.01 * best_f)

        # --- Nächste Struktur auswählen ---
        index = torch.argmax(log_ei).item()
        new_index = candidates.index[index]  # <-- wichtig für spätere Analyse
        best_indices.append(new_index)

        selected = pd.concat([selected, candidates.iloc[[index]]])
        best.append(selected[label].max())

        candidates = candidates.drop(new_index)  # <-- Tippfehler gefixt!

    print(f"Best Value after {len(best)} iterations: {best[-1]}")

    # --- Analyse ---
    mean_np = mean.detach().cpu().numpy().flatten()
    var_np = var.detach().cpu().numpy().flatten()
    std_np = np.sqrt(var_np)
    ei_np = torch.exp(log_ei).detach().cpu().numpy().flatten()

    best_f = train_y.max().item()
    z = (mean_np - best_f) / std_np
    pi_np = norm.cdf(z)

    # Test: Hat BO die beste Struktur gefunden?
    test_max(data, label, best_indices)

    return best

# %%
def test_max(data, label, best_indices):
    best_global = data[label].max()
    best_global_index = data[label].idxmax()

    print("\n=== Ergebnis-Check ===")
    print(f"Beste globale Struktur im Datensatz:")
    print(f"  Index: {best_global_index}")
    print(f"  Name: {data.loc[best_global_index, 'structure_name']}")
    print(f"  {label}: {best_global:.6f}")

    found_best = best_global_index in best_indices

    if found_best:
        print("\n✅ BO hat die globale beste Struktur gefunden!")
        return True
    else:
        print("\n⚠️ BO hat die globale beste Struktur NICHT gefunden!")
        return False

# %%
def get_temp_pressure_combinations(
    dft_path="/Users/danielbock/MASTERTHESIS/MASTA/DataArchiv/dft_fckin_clean_kond_64grid.csv",
    vext_str=None
):
    """DataArchiv/dft_fckin_clean_kond_64grid.csv
    Liefert sortierte Liste aller (temperature_kelvin, pressure_bar)-Kombinationen,
    die nach dem Merge beider CSVs tatsächlich vorkommen (beladung_mol_per_kg > 0).
    """
    dft_data = pd.read_csv(dft_path)
    expV_data = pd.read_csv(f"/Users/danielbock/MASTERTHESIS/MASTA/DataArchiv/Vext_allcsv/Vext_allTEMP_64grid_{vext_str}.csv")

    # Merge wie in data_gen
    merged = pd.merge(dft_data, expV_data, how='inner', on=["structure_name", "temperature_kelvin"])

    # Nur sinnvolle Daten
    if "beladung_mol_per_kg" in merged.columns:
        merged = merged[merged["beladung_mol_per_kg"] > 0]

    # (T, P)-Paare extrahieren
    if not {"temperature_kelvin", "pressure_bar"}.issubset(merged.columns):
        raise KeyError("Spalten 'temperature_kelvin' und/oder 'pressure_bar' fehlen nach dem Merge.")

    combos_df = (
        merged[["temperature_kelvin", "pressure_bar"]]
        .dropna()
        .drop_duplicates()
        .sort_values(["temperature_kelvin", "pressure_bar"])
    )
    combos = list(map(tuple, combos_df.to_numpy()))
    return combos

# %%
def append_log_row(
    log_path,
    row_dict,
    header_order=(
        "timestamp",
        "temperature_kelvin",
        "pressure_bar",
        "n_candidates",
        "n_iterations",
        "best_value",
        "global_best_value",
        "found_global_best",
        "vext_str"
    )
):
    """
    Hängt eine Zeile ans CSV an. Legt Datei mit Header an, falls sie fehlt.
    """
    file_exists = os.path.exists(log_path)
    with open(log_path, mode="a", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=header_order)
        if not file_exists:
            writer.writeheader()
        writer.writerow({k: row_dict.get(k, "") for k in header_order})

# %%
def run_all_BO(
    log_path="bo_results_fr.csv",
    vext_str=None,
    verbose=True
):
    """
    Durchläuft alle (T, P)-Kombinationen, führt data_gen → label_feature → BO_run aus,
    prüft per Vergleich max(best) vs. global_max, und loggt alles in log_path (Append).
    """
    combos = get_temp_pressure_combinations(vext_str=vext_str)
    if verbose:
        print(f"Gefundene Kombinationen: {len(combos)}")
        if len(combos) > 0:
            print("Erste 5:", combos[:5])

    for (T, P) in combos:
        if verbose:
            print("\n" + "="*72)
            print(f"Starte BO für T={T} K, P={P} bar")
            print("="*72)

        # --- Daten generieren (deine bestehende Funktion!) ---
        data, feature_cols = data_gen(temperature=T, pressure=P, vext_str=vext_str)

        # Safety-Checks
        if data is None or len(data) == 0:
            if verbose:
                print(f"[SKIP] Keine Daten für T={T}, P={P}.")
            append_log_row(log_path, {
                "timestamp": datetime.now().isoformat(timespec="seconds"),
                "temperature_kelvin": T,
                "pressure_bar": P,
                "n_candidates": 0,
                "n_iterations": 0,
                "best_value": "",
                "global_best_value": "",
                "found_global_best": False,
                "vext_str": str(vext_str)
            })
            continue

        if verbose:
            print(f"→ Kandidaten vor Filter: {len(data)}")

        # --- label_feature erwartet globales feature_columns (deine Logik beibehalten) ---
        globals()["feature_columns"] = feature_cols
        data, label = label_feature(data, feature_columns)

        # Nach label_feature nochmal prüfen (z. B. falls Filtering leer macht)
        if data is None or len(data) == 0:
            if verbose:
                print(f"[SKIP] Nach label_feature keine Daten mehr für T={T}, P={P}.")
            append_log_row(log_path, {
                "timestamp": datetime.now().isoformat(timespec="seconds"),
                "temperature_kelvin": T,
                "pressure_bar": P,
                "n_candidates": 0,
                "n_iterations": 0,
                "best_value": "",
                "global_best_value": "",
                "found_global_best": False,
                "vext_str": str(vext_str)
            })
            continue

        # --- BO laufen lassen (deine bestehende Funktion!) ---
        try:
            best_list = BO_run(data, label, feature_cols)  # sichtbare Prints macht BO_run selbst
        except Exception as e:
            if verbose:
                print(f"[ERROR] BO_run fehlgeschlagen für T={T}, P={P}: {e}")
            append_log_row(log_path, {
                "timestamp": datetime.now().isoformat(timespec="seconds"),
                "temperature_kelvin": T,
                "pressure_bar": P,
                "n_candidates": len(data),
                "n_iterations": 0,
                "best_value": "",
                "global_best_value": "",
                "found_global_best": False,
                "vext_str": str(vext_str)
            })
            continue

        # --- Erfolg prüfen (ohne best_indices; robust über Wertevergleich) ---
        try:
            best_value = float(np.max(best_list)) if len(best_list) else float("nan")
        except Exception:
            # Falls dtype Probleme (np.float64-Objekte), robust casten:
            best_value = float(np.max([float(x) for x in best_list])) if len(best_list) else float("nan")

        global_best_value = float(data[label].max())
        found_global = bool(np.isclose(best_value, global_best_value, rtol=1e-10, atol=1e-14))
        n_iterations = max(len(best_list) - 1, 0)

        if verbose:
            print(f"\n[SUMMARY] T={T} K, P={P} bar")
            print(f"  Kandidaten:            {len(data)}")
            print(f"  Iterationen (eff.):    {n_iterations}")
            print(f"  BO best_value:         {best_value:.12g}")
            print(f"  Global best in subset: {global_best_value:.12g}")
            print("  Treffer global best?:  " + ("✅ JA" if found_global else "❌ NEIN"))

        # --- Log schreiben ---
        append_log_row(log_path, {
            "timestamp": datetime.now().isoformat(timespec="seconds"),
            "temperature_kelvin": T,
            "pressure_bar": P,
            "n_candidates": len(data),
            "n_iterations": n_iterations,
            "best_value": best_value,
            "global_best_value": global_best_value,
            "found_global_best": found_global,
            "vext_str": str(vext_str)
        })

    if verbose:
        print("\nFertig. Ergebnisse geloggt nach:", os.path.abspath(log_path))

# %%
from glob import glob
import os

vext_files = glob("/Users/danielbock/MASTERTHESIS/MASTA/DataArchiv/Vext_allcsv/Vext_allTEMP_64grid_*.csv")

for file_path in vext_files:
    # Molekülname aus dem Dateinamen extrahieren
    vext_str = os.path.basename(file_path).replace("Vext_allTEMP_64grid_", "").replace(".csv", "")

    run_all_BO(
        log_path=f"bo_log_cleankond_{vext_str}.csv",
        vext_str=vext_str,
        verbose=False
    )
# Out:
# Initial training points:
#   Index 105, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 12 due to no improvement in the last 10 iterations.
# Best Value after 13 iterations: 0.001960839017015396
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 58
#   Name: DOH
#   beladung_pro_vol: 0.003369
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 232, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 12 due to no improvement in the last 10 iterations.
# Best Value after 13 iterations: 0.0037008755204272323
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 205
#   Name: AFY
#   beladung_pro_vol: 0.005249
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 359, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.004580186055383727
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 332
#   Name: AFY
#   beladung_pro_vol: 0.005844
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 486, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.004808435222698464
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 459
#   Name: AFY
#   beladung_pro_vol: 0.006082
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 613, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 19 due to no improvement in the last 10 iterations.
# Best Value after 20 iterations: 0.00621938058649801
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 586
#   Name: AFY
#   beladung_pro_vol: 0.006219
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 740, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 19 due to no improvement in the last 10 iterations.
# Best Value after 20 iterations: 0.005061590275813522
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 713
#   Name: AFY
#   beladung_pro_vol: 0.006313
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 867, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 19 due to no improvement in the last 10 iterations.
# Best Value after 20 iterations: 0.005142577045859217
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 771
#   Name: JST
#   beladung_pro_vol: 0.006512
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 994, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 19 due to no improvement in the last 10 iterations.
# Best Value after 20 iterations: 0.005200617561517126
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 898
#   Name: JST
#   beladung_pro_vol: 0.006818
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 1121, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 19 due to no improvement in the last 10 iterations.
# Best Value after 20 iterations: 0.005263907123872509
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1025
#   Name: JST
#   beladung_pro_vol: 0.007036
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 1258, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 19 due to no improvement in the last 10 iterations.
# Best Value after 20 iterations: 0.005317034781486939
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1192
#   Name: JST
#   beladung_pro_vol: 0.007198
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 1384, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 27 due to no improvement in the last 10 iterations.
# Best Value after 28 iterations: 0.007322366432814224
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1318
#   Name: JST
#   beladung_pro_vol: 0.007322
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 1510, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 27 due to no improvement in the last 10 iterations.
# Best Value after 28 iterations: 0.00742134321309452
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1444
#   Name: JST
#   beladung_pro_vol: 0.007421
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 1636, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 27 due to no improvement in the last 10 iterations.
# Best Value after 28 iterations: 0.007501736040177869
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1570
#   Name: JST
#   beladung_pro_vol: 0.007502
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 1761, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.005492947197706396
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1696
#   Name: JST
#   beladung_pro_vol: 0.007568
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 1886, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.0055786117081394245
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1821
#   Name: JST
#   beladung_pro_vol: 0.007624
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 2002, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 29 due to no improvement in the last 10 iterations.
# Best Value after 30 iterations: 0.0027296605148801963
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1955
#   Name: DOH
#   beladung_pro_vol: 0.002730
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 2129, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.002947747725564424
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2082
#   Name: DOH
#   beladung_pro_vol: 0.003465
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 2256, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.003635790582825116
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2229
#   Name: AFY
#   beladung_pro_vol: 0.003938
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 2383, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 14 due to no improvement in the last 10 iterations.
# Best Value after 15 iterations: 0.004641911718819257
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2356
#   Name: AFY
#   beladung_pro_vol: 0.004642
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 2510, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 14 due to no improvement in the last 10 iterations.
# Best Value after 15 iterations: 0.005051487662179671
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2483
#   Name: AFY
#   beladung_pro_vol: 0.005051
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 2637, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 14 due to no improvement in the last 10 iterations.
# Best Value after 15 iterations: 0.0053171953217276855
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2610
#   Name: AFY
#   beladung_pro_vol: 0.005317
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 2764, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 14 due to no improvement in the last 10 iterations.
# Best Value after 15 iterations: 0.005504151272041705
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2737
#   Name: AFY
#   beladung_pro_vol: 0.005504
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 2891, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 25 due to no improvement in the last 10 iterations.
# Best Value after 26 iterations: 0.0045820842599398216
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2864
#   Name: AFY
#   beladung_pro_vol: 0.005644
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3018, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 23 due to no improvement in the last 10 iterations.
# Best Value after 24 iterations: 0.004663275608682597
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2991
#   Name: AFY
#   beladung_pro_vol: 0.005753
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3145, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 23 due to no improvement in the last 10 iterations.
# Best Value after 24 iterations: 0.004732303530121139
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3118
#   Name: AFY
#   beladung_pro_vol: 0.005840
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3272, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 25 due to no improvement in the last 10 iterations.
# Best Value after 26 iterations: 0.004792094789936462
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3245
#   Name: AFY
#   beladung_pro_vol: 0.005913
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3399, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 23 due to no improvement in the last 10 iterations.
# Best Value after 24 iterations: 0.005974572141081259
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3372
#   Name: AFY
#   beladung_pro_vol: 0.005975
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 3526, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 25 due to no improvement in the last 10 iterations.
# Best Value after 26 iterations: 0.004891445095420893
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3499
#   Name: AFY
#   beladung_pro_vol: 0.006027
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3653, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 23 due to no improvement in the last 10 iterations.
# Best Value after 24 iterations: 0.006073656658624628
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3626
#   Name: AFY
#   beladung_pro_vol: 0.006074
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 3780, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 23 due to no improvement in the last 10 iterations.
# Best Value after 24 iterations: 0.006114445175656172
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3753
#   Name: AFY
#   beladung_pro_vol: 0.006114
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 3907, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 19 due to no improvement in the last 10 iterations.
# Best Value after 20 iterations: 0.0015268014077681371
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3860
#   Name: DOH
#   beladung_pro_vol: 0.001527
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4034, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 31 due to no improvement in the last 10 iterations.
# Best Value after 32 iterations: 0.0031191161306986935
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3987
#   Name: DOH
#   beladung_pro_vol: 0.003119
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4161, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 32 due to no improvement in the last 10 iterations.
# Best Value after 33 iterations: 0.0033350512156347313
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4114
#   Name: DOH
#   beladung_pro_vol: 0.003335
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4288, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 31 due to no improvement in the last 10 iterations.
# Best Value after 32 iterations: 0.0034306377627992962
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4241
#   Name: DOH
#   beladung_pro_vol: 0.003431
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4415, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 20 due to no improvement in the last 10 iterations.
# Best Value after 21 iterations: 0.0032870509541968428
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4368
#   Name: DOH
#   beladung_pro_vol: 0.003489
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 4542, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.003653937876805258
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4515
#   Name: AFY
#   beladung_pro_vol: 0.003654
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4669, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.003985970393262322
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4642
#   Name: AFY
#   beladung_pro_vol: 0.003986
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4796, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.003855775878662344
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4769
#   Name: AFY
#   beladung_pro_vol: 0.004253
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 4923, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.003975355514128941
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4896
#   Name: AFY
#   beladung_pro_vol: 0.004472
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5050, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.0040760861178005935
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5023
#   Name: AFY
#   beladung_pro_vol: 0.004653
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5177, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.004162625297381026
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5150
#   Name: AFY
#   beladung_pro_vol: 0.004806
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5304, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.004238155991720673
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5277
#   Name: AFY
#   beladung_pro_vol: 0.004937
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5431, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.00430493705679439
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5404
#   Name: AFY
#   beladung_pro_vol: 0.005050
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5558, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.004364633882498772
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5531
#   Name: AFY
#   beladung_pro_vol: 0.005148
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5685, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.004418488306613445
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5658
#   Name: AFY
#   beladung_pro_vol: 0.005235
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5812, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 23 due to no improvement in the last 10 iterations.
# Best Value after 24 iterations: 0.0006179148721978325
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5765
#   Name: DOH
#   beladung_pro_vol: 0.000618
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 5939, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 28 due to no improvement in the last 10 iterations.
# Best Value after 29 iterations: 0.0024634003558000623
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5892
#   Name: DOH
#   beladung_pro_vol: 0.002463
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6066, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 29 due to no improvement in the last 10 iterations.
# Best Value after 30 iterations: 0.002908687448755776
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6019
#   Name: DOH
#   beladung_pro_vol: 0.002909
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6193, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 22 due to no improvement in the last 10 iterations.
# Best Value after 23 iterations: 0.0031071553880118274
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6146
#   Name: DOH
#   beladung_pro_vol: 0.003107
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6320, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 14 due to no improvement in the last 10 iterations.
# Best Value after 15 iterations: 0.0020196054650728477
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6273
#   Name: DOH
#   beladung_pro_vol: 0.003222
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 6447, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 29 due to no improvement in the last 10 iterations.
# Best Value after 30 iterations: 0.0032988940321091063
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6400
#   Name: DOH
#   beladung_pro_vol: 0.003299
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6574, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 29 due to no improvement in the last 10 iterations.
# Best Value after 30 iterations: 0.0033546420038158557
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6527
#   Name: DOH
#   beladung_pro_vol: 0.003355
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6701, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.0028375591771323426
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6654
#   Name: DOH
#   beladung_pro_vol: 0.003398
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 6828, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.003072567966740601
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6781
#   Name: DOH
#   beladung_pro_vol: 0.003432
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 6955, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.003282393469163406
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6908
#   Name: DOH
#   beladung_pro_vol: 0.003461
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 7082, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 24 due to no improvement in the last 10 iterations.
# Best Value after 25 iterations: 0.003485589539429307
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7035
#   Name: DOH
#   beladung_pro_vol: 0.003486
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 7209, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.003639581191109244
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7182
#   Name: AFY
#   beladung_pro_vol: 0.003640
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 7336, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0037923202045961266
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7309
#   Name: AFY
#   beladung_pro_vol: 0.003792
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 7463, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.003697279828938637
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7436
#   Name: AFY
#   beladung_pro_vol: 0.003931
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 7590, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.003773316248101413
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7563
#   Name: AFY
#   beladung_pro_vol: 0.004057
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 7717, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 20 due to no improvement in the last 10 iterations.
# Best Value after 21 iterations: 0.0002692611580099801
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7670
#   Name: DOH
#   beladung_pro_vol: 0.000269
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 7844, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 23 due to no improvement in the last 10 iterations.
# Best Value after 24 iterations: 0.001607250724959647
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7797
#   Name: DOH
#   beladung_pro_vol: 0.001607
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 7971, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 21 due to no improvement in the last 10 iterations.
# Best Value after 22 iterations: 0.0022375062671857477
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7924
#   Name: DOH
#   beladung_pro_vol: 0.002238
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8098, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 21 due to no improvement in the last 10 iterations.
# Best Value after 22 iterations: 0.002572609497429834
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8051
#   Name: DOH
#   beladung_pro_vol: 0.002573
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8225, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 21 due to no improvement in the last 10 iterations.
# Best Value after 22 iterations: 0.002778486110099256
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8178
#   Name: DOH
#   beladung_pro_vol: 0.002778
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8352, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 23 due to no improvement in the last 10 iterations.
# Best Value after 24 iterations: 0.0029182261878288305
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8305
#   Name: DOH
#   beladung_pro_vol: 0.002918
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8479, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 23 due to no improvement in the last 10 iterations.
# Best Value after 24 iterations: 0.003019832598815162
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8432
#   Name: DOH
#   beladung_pro_vol: 0.003020
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8606, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 21 due to no improvement in the last 10 iterations.
# Best Value after 22 iterations: 0.003097465302318148
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8559
#   Name: DOH
#   beladung_pro_vol: 0.003097
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8733, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 20 due to no improvement in the last 10 iterations.
# Best Value after 21 iterations: 0.0031590519610855744
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8686
#   Name: DOH
#   beladung_pro_vol: 0.003159
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8860, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 20 due to no improvement in the last 10 iterations.
# Best Value after 21 iterations: 0.003209350761487735
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8813
#   Name: DOH
#   beladung_pro_vol: 0.003209
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8987, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 20 due to no improvement in the last 10 iterations.
# Best Value after 21 iterations: 0.0032514082282107007
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8940
#   Name: DOH
#   beladung_pro_vol: 0.003251
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 9114, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 22 due to no improvement in the last 10 iterations.
# Best Value after 23 iterations: 0.0032872504943117255
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 9067
#   Name: DOH
#   beladung_pro_vol: 0.003287
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 9241, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 22 due to no improvement in the last 10 iterations.
# Best Value after 23 iterations: 0.0033182855527051883
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 9194
#   Name: DOH
#   beladung_pro_vol: 0.003318
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 9368, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 22 due to no improvement in the last 10 iterations.
# Best Value after 23 iterations: 0.003345520950563474
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 9321
#   Name: DOH
#   beladung_pro_vol: 0.003346
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 9495, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 22 due to no improvement in the last 10 iterations.
# Best Value after 23 iterations: 0.0033696972542675567
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 9448
#   Name: DOH
#   beladung_pro_vol: 0.003370
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 105, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 19 due to no improvement in the last 10 iterations.
# Best Value after 20 iterations: 0.0033685287399680677
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 58
#   Name: DOH
#   beladung_pro_vol: 0.003369
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 232, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 19 due to no improvement in the last 10 iterations.
# Best Value after 20 iterations: 0.0038155809250535765
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 205
#   Name: AFY
#   beladung_pro_vol: 0.005249
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 359, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 12 due to no improvement in the last 10 iterations.
# Best Value after 13 iterations: 0.003148477017798461
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 332
#   Name: AFY
#   beladung_pro_vol: 0.005844
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 486, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 12 due to no improvement in the last 10 iterations.
# Best Value after 13 iterations: 0.0032828857293083257
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 459
#   Name: AFY
#   beladung_pro_vol: 0.006082
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 613, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 12 due to no improvement in the last 10 iterations.
# Best Value after 13 iterations: 0.003313109938749145
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 586
#   Name: AFY
#   beladung_pro_vol: 0.006219
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 740, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 12 due to no improvement in the last 10 iterations.
# Best Value after 13 iterations: 0.003355604227482107
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 713
#   Name: AFY
#   beladung_pro_vol: 0.006313
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 867, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 12 due to no improvement in the last 10 iterations.
# Best Value after 13 iterations: 0.0033760570036725185
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 771
#   Name: JST
#   beladung_pro_vol: 0.006512
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 994, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 12 due to no improvement in the last 10 iterations.
# Best Value after 13 iterations: 0.0033929011387070543
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 898
#   Name: JST
#   beladung_pro_vol: 0.006818
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 1121, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 12 due to no improvement in the last 10 iterations.
# Best Value after 13 iterations: 0.0034069054823739455
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1025
#   Name: JST
#   beladung_pro_vol: 0.007036
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 1258, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 20 due to no improvement in the last 10 iterations.
# Best Value after 21 iterations: 0.003420475542794134
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1192
#   Name: JST
#   beladung_pro_vol: 0.007198
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 1384, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.0034599166267847816
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1318
#   Name: JST
#   beladung_pro_vol: 0.007322
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 1510, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.003496064861749019
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1444
#   Name: JST
#   beladung_pro_vol: 0.007421
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 1636, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 36 due to no improvement in the last 10 iterations.
# Best Value after 37 iterations: 0.004671544058337283
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1570
#   Name: JST
#   beladung_pro_vol: 0.007502
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 1761, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 51 due to no improvement in the last 10 iterations.
# Best Value after 52 iterations: 0.0058763234305720825
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1696
#   Name: JST
#   beladung_pro_vol: 0.007568
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 1886, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.003589329857898416
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1821
#   Name: JST
#   beladung_pro_vol: 0.007624
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 2002, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.0027296605148801963
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 1955
#   Name: DOH
#   beladung_pro_vol: 0.002730
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 2129, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.0034649507797094993
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2082
#   Name: DOH
#   beladung_pro_vol: 0.003465
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 2256, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.003568248002190072
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2229
#   Name: AFY
#   beladung_pro_vol: 0.003938
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 2383, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.003620001581330422
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2356
#   Name: AFY
#   beladung_pro_vol: 0.004642
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 2510, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 13 due to no improvement in the last 10 iterations.
# Best Value after 14 iterations: 0.004203977766298339
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2483
#   Name: AFY
#   beladung_pro_vol: 0.005051
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 2637, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 24 due to no improvement in the last 10 iterations.
# Best Value after 25 iterations: 0.0043625252589243645
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2610
#   Name: AFY
#   beladung_pro_vol: 0.005317
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 2764, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 22 due to no improvement in the last 10 iterations.
# Best Value after 23 iterations: 0.004484259206075378
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2737
#   Name: AFY
#   beladung_pro_vol: 0.005504
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 2891, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 28 due to no improvement in the last 10 iterations.
# Best Value after 29 iterations: 0.00395187869139334
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2864
#   Name: AFY
#   beladung_pro_vol: 0.005644
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3018, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.003908742661419199
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 2991
#   Name: AFY
#   beladung_pro_vol: 0.005753
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3145, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.004020045176154927
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3118
#   Name: AFY
#   beladung_pro_vol: 0.005840
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3272, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 21 due to no improvement in the last 10 iterations.
# Best Value after 22 iterations: 0.004792094789936462
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3245
#   Name: AFY
#   beladung_pro_vol: 0.005913
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3399, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0041997389719177994
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3372
#   Name: AFY
#   beladung_pro_vol: 0.005975
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3526, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.004263790032647119
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3499
#   Name: AFY
#   beladung_pro_vol: 0.006027
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3653, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.004560078059619608
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3626
#   Name: AFY
#   beladung_pro_vol: 0.006074
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3780, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.004575367255400831
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3753
#   Name: AFY
#   beladung_pro_vol: 0.006114
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 3907, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0015268014077681371
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3860
#   Name: DOH
#   beladung_pro_vol: 0.001527
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4034, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0031191161306986935
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 3987
#   Name: DOH
#   beladung_pro_vol: 0.003119
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4161, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0033350512156347313
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4114
#   Name: DOH
#   beladung_pro_vol: 0.003335
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4288, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0034306377627992962
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4241
#   Name: DOH
#   beladung_pro_vol: 0.003431
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4415, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0034887587614284023
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4368
#   Name: DOH
#   beladung_pro_vol: 0.003489
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4542, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.003529896928892783
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4515
#   Name: AFY
#   beladung_pro_vol: 0.003654
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 4669, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 22 due to no improvement in the last 10 iterations.
# Best Value after 23 iterations: 0.0037102511186644415
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4642
#   Name: AFY
#   beladung_pro_vol: 0.003986
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 4796, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 23 due to no improvement in the last 10 iterations.
# Best Value after 24 iterations: 0.003855775878662344
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4769
#   Name: AFY
#   beladung_pro_vol: 0.004253
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 4923, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.003609480817418631
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4896
#   Name: AFY
#   beladung_pro_vol: 0.004472
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5050, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.0036285306263998418
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5023
#   Name: AFY
#   beladung_pro_vol: 0.004653
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5177, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.003648258358384202
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5150
#   Name: AFY
#   beladung_pro_vol: 0.004806
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5304, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.003663623025517628
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5277
#   Name: AFY
#   beladung_pro_vol: 0.004937
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5431, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.0036847261517741485
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5404
#   Name: AFY
#   beladung_pro_vol: 0.005050
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5558, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.003703311320874094
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5531
#   Name: AFY
#   beladung_pro_vol: 0.005148
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5685, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.0037194498031929155
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5658
#   Name: AFY
#   beladung_pro_vol: 0.005235
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5812, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0006179148721978325
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5765
#   Name: DOH
#   beladung_pro_vol: 0.000618
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 5939, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.0024634003558000623
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5892
#   Name: DOH
#   beladung_pro_vol: 0.002463
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6066, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.002908687448755776
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6019
#   Name: DOH
#   beladung_pro_vol: 0.002909
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6193, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 14 due to no improvement in the last 10 iterations.
# Best Value after 15 iterations: 0.0031071553880118274
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6146
#   Name: DOH
#   beladung_pro_vol: 0.003107
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6320, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0032222115404827545
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6273
#   Name: DOH
#   beladung_pro_vol: 0.003222
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6447, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.0032988940321091063
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6400
#   Name: DOH
#   beladung_pro_vol: 0.003299
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6574, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 18 due to no improvement in the last 10 iterations.
# Best Value after 19 iterations: 0.0033546420038158557
#
# === Ergebnis-Check ===
# ...
#   Index: 4114
#   Name: DOH
#   beladung_pro_vol: 0.003335
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4288, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.0034306377627992962
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4241
#   Name: DOH
#   beladung_pro_vol: 0.003431
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4415, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.0034887587614284023
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4368
#   Name: DOH
#   beladung_pro_vol: 0.003489
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 4542, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.003529896928892783
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4515
#   Name: AFY
#   beladung_pro_vol: 0.003654
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 4669, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.003561666868871049
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4642
#   Name: AFY
#   beladung_pro_vol: 0.003986
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 4796, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.003587558588536414
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4769
#   Name: AFY
#   beladung_pro_vol: 0.004253
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 4923, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.003975355514128941
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 4896
#   Name: AFY
#   beladung_pro_vol: 0.004472
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5050, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.0040760861178005935
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5023
#   Name: AFY
#   beladung_pro_vol: 0.004653
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5177, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.003648258358384202
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5150
#   Name: AFY
#   beladung_pro_vol: 0.004806
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5304, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.004238155991720673
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5277
#   Name: AFY
#   beladung_pro_vol: 0.004937
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5431, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.0036847261517741485
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5404
#   Name: AFY
#   beladung_pro_vol: 0.005050
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5558, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.004364633882498772
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5531
#   Name: AFY
#   beladung_pro_vol: 0.005148
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5685, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0037194498031929155
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5658
#   Name: AFY
#   beladung_pro_vol: 0.005235
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 5812, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.0006179148721978325
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5765
#   Name: DOH
#   beladung_pro_vol: 0.000618
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 5939, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0024634003558000623
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 5892
#   Name: DOH
#   beladung_pro_vol: 0.002463
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6066, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.002908687448755776
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6019
#   Name: DOH
#   beladung_pro_vol: 0.002909
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6193, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 15 due to no improvement in the last 10 iterations.
# Best Value after 16 iterations: 0.0031071553880118274
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6146
#   Name: DOH
#   beladung_pro_vol: 0.003107
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6320, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0032222115404827545
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6273
#   Name: DOH
#   beladung_pro_vol: 0.003222
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6447, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 17 due to no improvement in the last 10 iterations.
# Best Value after 18 iterations: 0.0032988940321091063
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6400
#   Name: DOH
#   beladung_pro_vol: 0.003299
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6574, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 16 due to no improvement in the last 10 iterations.
# Best Value after 17 iterations: 0.0033546420038158557
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6527
#   Name: DOH
#   beladung_pro_vol: 0.003355
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6701, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 14 due to no improvement in the last 10 iterations.
# Best Value after 15 iterations: 0.0033976450452949418
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6654
#   Name: DOH
#   beladung_pro_vol: 0.003398
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6828, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 19 due to no improvement in the last 10 iterations.
# Best Value after 20 iterations: 0.003432267062679214
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6781
#   Name: DOH
#   beladung_pro_vol: 0.003432
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 6955, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.0031121921358326604
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 6908
#   Name: DOH
#   beladung_pro_vol: 0.003461
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 7082, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 20 due to no improvement in the last 10 iterations.
# Best Value after 21 iterations: 0.003485589539429307
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7035
#   Name: DOH
#   beladung_pro_vol: 0.003486
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 7209, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 19 due to no improvement in the last 10 iterations.
# Best Value after 20 iterations: 0.003506922196674595
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7182
#   Name: AFY
#   beladung_pro_vol: 0.003640
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 7336, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 20 due to no improvement in the last 10 iterations.
# Best Value after 21 iterations: 0.0035257680011731786
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7309
#   Name: AFY
#   beladung_pro_vol: 0.003792
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 7463, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.0033227287368815957
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7436
#   Name: AFY
#   beladung_pro_vol: 0.003931
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 7590, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 11 due to no improvement in the last 10 iterations.
# Best Value after 12 iterations: 0.0033600754802408472
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7563
#   Name: AFY
#   beladung_pro_vol: 0.004057
#
# ⚠️ BO hat die globale beste Struktur NICHT gefunden!
# Initial training points:
#   Index 7717, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.0002692611580099801
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7670
#   Name: DOH
#   beladung_pro_vol: 0.000269
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 7844, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.001607250724959647
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7797
#   Name: DOH
#   beladung_pro_vol: 0.001607
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 7971, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.0022375062671857477
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 7924
#   Name: DOH
#   beladung_pro_vol: 0.002238
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8098, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.002572609497429834
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8051
#   Name: DOH
#   beladung_pro_vol: 0.002573
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8225, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.002778486110099256
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8178
#   Name: DOH
#   beladung_pro_vol: 0.002778
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8352, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.0029182261878288305
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8305
#   Name: DOH
#   beladung_pro_vol: 0.002918
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8479, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.003019832598815162
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8432
#   Name: DOH
#   beladung_pro_vol: 0.003020
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8606, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.003097465302318148
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8559
#   Name: DOH
#   beladung_pro_vol: 0.003097
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8733, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.0031590519610855744
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8686
#   Name: DOH
#   beladung_pro_vol: 0.003159
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8860, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.003209350761487735
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8813
#   Name: DOH
#   beladung_pro_vol: 0.003209
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 8987, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.0032514082282107007
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 8940
#   Name: DOH
#   beladung_pro_vol: 0.003251
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 9114, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.0032872504943117255
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 9067
#   Name: DOH
#   beladung_pro_vol: 0.003287
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 9241, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.0033182855527051883
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 9194
#   Name: DOH
#   beladung_pro_vol: 0.003318
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 9368, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.003345520950563474
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 9321
#   Name: DOH
#   beladung_pro_vol: 0.003346
#
# ✅ BO hat die globale beste Struktur gefunden!
# Initial training points:
#   Index 9495, Structure LIT, beladung_pro_vol: 0.0000
# Early stopping at iteration 10 due to no improvement in the last 10 iterations.
# Best Value after 11 iterations: 0.0033696972542675567
#
# === Ergebnis-Check ===
# Beste globale Struktur im Datensatz:
#   Index: 9448
#   Name: DOH
#   beladung_pro_vol: 0.003370
#
# ✅ BO hat die globale beste Struktur gefunden!
